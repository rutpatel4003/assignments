# %%
# !git clone https://github.com/harry2141985/DiffFace.git # Download the FaceDiff model and files from here
# Out:
# fatal: destination path 'DiffFace' already exists and is not an empty directory.

# %%
# Install the PyTorch and other libraries versions mentioned here, requirements folder is present in the main folder
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html
# %cd "/kaggle/working/DiffFace/"
# !pip install -r requirements.txt
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
# /kaggle/working/DiffFace
# ...

# %%
# !pip install gdown
import gdown

output = "/kaggle/working/DiffFace/checkpoints.zip" # Save the file in the folder

gdown.download(f"https://drive.google.com/uc?id=1z7u38LsVaPV2ew_Ci_YLf48i-_Cge8po", output, quiet=False) # Download the files using gzip

# %cd "/kaggle/working/DiffFace/DiffFace/"

# !unzip checkpoints.zip # Unzip the checkpoints.zip
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1z7u38LsVaPV2ew_Ci_YLf48i-_Cge8po
# From (redirected): https://drive.google.com/uc?id=1z7u38LsVaPV2ew_Ci_YLf48i-_Cge8po&confirm=t&uuid=79997d5f-dd16-4aa8-9aee-34ab16d5e0c1
# To: /kaggle/working/DiffFace/checkpoints.zip
# 100%|██████████| 3.07G/3.07G [00:53<00:00, 57.6MB/s]
# [Errno 2] No such file or directory: '/kaggle/working/DiffFace/DiffFace/'
# /kaggle/working/DiffFace
# Archive:  checkpoints.zip
#  extracting: checkpoints/Arcface.tar
#  extracting: checkpoints/FaceParser.pth
#  extracting: checkpoints/GazeEstimator.pt
#  extracting: checkpoints/Model.pt

# %%
# If you're running the file on kaggle - make sure to install the uncomment the below two lines first
# !pip install cmake
# !pip install dlib
# Out:
# ...
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for dlib: filename=dlib-19.24.6-cp310-cp310-linux_x86_64.whl size=3590663 sha256=95833b06acd00965ba4f6bab68b1efb5b45d23047e88f26a372550a81497855d
#   Stored in directory: /root/.cache/pip/wheels/7c/1d/d1/e69ceb001441acedfa6156acda6c1856699e260ea1a9e6dcc4
# Successfully built dlib
# ...

# %%
import shutil
# %cd "/kaggle/working/DiffFace/"
# Run the cell first, if the directories data/debug, data/dst, data/src do not exist, they will be created
# Name your file whose face you want to get swapped aka keep the body as "src.png"/ "src.jpg"
# Name your file whose face you want to swap with aka the face as "dst.png"/ "dst.jpg"
# Upload the files by going to the Notebook on the right --> Input --> Upload --> New Dataset --> Choose the files --> Name the dataset --> OK
# Shift the "src.png" to data/src and shift the "dst.png" to data/src and then run the code and your model will start training 

# Uncomment the below lines for shifting the data only if you're using kaggle, or else drag and drop works on Colab
# src_path = r"/kaggle/input/images/src.png"
# dst_path = r"/kaggle/working/DiffFace/data/src"
# shutil.copy(src_path, dst_path)
# print('Copied')
# src_path = r"/kaggle/input/images/dst.png"
# dst_path = r"/kaggle/working/DiffFace/data/dst"
# shutil.copy(src_path, dst_path)
# print('Copied')


# You can choose your own loss, iterations, output path, and other features too which can be looked up on the reference given in the documentation
# You can directly access the reference here: https://hxngiee.github.io/DiffFace/
# !python main.py --iterations_num 3 --loss_weight 4000 --output_path output/final

# The data will be stored in /kaggle/working/DiffFace/output/final after it trains
# Out:
# /kaggle/working/DiffFace
# Copied
# Copied
# Checking source directory:
# ['src.png', 'aligned']
# Checking destination directory:
# ['dst.png', 'merged', 'preded', 'aligned']
# Files found with pattern: ./data/src/src.*
# Files found with pattern: ./data/dst/dst.*
# Source Extension: png
# Destination Extension: png
# Requested Crop
# Downloading: "https://github.com/mantasu/face-crop-plus/releases/download/v1.0.0/retinaface_detector.pth" to /root/.cache/torch/hub/checkpoints/retinaface_detector.pth
# 100%|████████████████████████████████████████| 104M/104M [00:02<00:00, 50.1MB/s]
# Processing:   0%|                                         | 0/1 [00:00<?, ?it/s]/kaggle/working/DiffFace/face_crop_plus/utils.py:264: UserWarning: Could not read the image ./data/src/aligned
#   warnings.warn(f"Could not read the image {path}")
# ...
